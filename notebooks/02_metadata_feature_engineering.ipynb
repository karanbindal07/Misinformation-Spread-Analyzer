# %% [markdown]
# This notebook loads and verifies the engineered metadata features produced by src/features_metadata.py. These features are used in the improved metadata model.

# %%
import pandas as pd

df = pd.read_csv("../data/processed/covid_misinfo_metadata_features.csv")

print("Shape:", df.shape)
print("Columns:", df.columns)
df.head()
# Out:
# Shape: (195843, 20)
# Columns: Index(['id', 'graph_id', 'label', 'time', 'friends', 'followers',
#        'log_followers', 'log_friends', 'followers_per_friend',
#        'friends_per_follower', 'followers_x_friends',
#        'time_bin_(105334.4, 192032.4]', 'time_bin_(12422.8, 29139.0]',
#        'time_bin_(1812591.4, 244196420.0]', 'time_bin_(192032.4, 452590.0]',
#        'time_bin_(2782.2, 12422.8]', 'time_bin_(29139.0, 49633.8]',
#        'time_bin_(452590.0, 1812591.4]', 'time_bin_(49633.8, 72728.0]',
#        'time_bin_(72728.0, 105334.4]'],
#       dtype='object')
#           id  graph_id  label    time  friends  followers  log_followers  \
# 0  582746618      1069      0   35312        8          6       1.945910
# 1   83528167      1069      0   22636        9          7       2.079442
# 2  611354762      1069      0   32483        7          9       2.302585
# 3  129109380      1069      0  115680        8          6       1.945910
# ...
